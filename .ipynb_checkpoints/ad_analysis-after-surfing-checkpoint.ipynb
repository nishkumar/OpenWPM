# %%
from bs4 import BeautifulSoup
import PIL.Image as Image
import urllib2
from urlparse import urlparse
import os

# %%
# html_files = []
# for file in os.listdir(os.getcwd()+'/sources'):
#     html_files.append(file)

# %%
import requests
from fake_useragent import UserAgent
ua = UserAgent()

# urls = ['https://www.google.com/search?q=men+shoes&oq=men+shoes&aqs=chrome..69i57j0l5.5806j0j1&sourceid=chrome&ie=UTF-8','https://www.amazon.com/gp/product/B07CNRZHBN/ref=s9_acsd_newrz_hd_bw_bjy9Q3_c_x_w?pf_rd_m=ATVPDKIKX0DER&pf_rd_s=merchandised-search-4&pf_rd_r=0BB043CDPR0Z274FKPQQ&pf_rd_t=101&pf_rd_p=2408ad10-ec7d-58bf-b720-d2b39257802f&pf_rd_i=679271011','https://www.menswearhouse.com/clearance/mens-shoes-clearance?gclid=Cj0KCQjw5-TXBRCHARIsANLixNw2FQhcGXVkWECyU0XKnPWOWffYS-royR9ivz2HNYRKnmsLduYh9GwaAuvNEALw_wcB','https://www.amazon.com/b/ref=s9_acsd_hfnv_hd_bw_b6ghUuB_ct_x_ct01_w?_encoding=UTF8&node=679271011&pf_rd_m=ATVPDKIKX0DER&pf_rd_s=merchandised-search-4&pf_rd_r=7XARSR0ZB2ZN8XGNEG7A&pf_rd_t=101&pf_rd_p=d48b4899-ec24-574d-bd65-0485cc7f6833&pf_rd_i=6127770011','https://www.amazon.com/gp/product/B078H9Z1S5/ref=s9_acsd_top_hd_bw_bjy9Q3_c_x_1_w?pf_rd_m=ATVPDKIKX0DER&pf_rd_s=merchandised-search-3&pf_rd_r=0BB043CDPR0Z274FKPQQ&pf_rd_t=101&pf_rd_p=2408ad10-ec7d-58bf-b720-d2b39257802f&pf_rd_i=679271011','http://www.yahoo.com']
headers = {'User-Agent': ua.chrome}
urls = ['https://www.yahoo.com']
for url in urls:
    response = requests.get(url, headers=headers)

# %%
# url = 'https://www.rediff.com/'
# print url
# urlContent = urllib2.urlopen(url).read()

# soup = BeautifulSoup(''.join(urlContent))
soup = BeautifulSoup(response.content)

# HTML = open('sources/' + html_files[3]).read()
# soup= BeautifulSoup(HTML, 'html.parser')
# print html_files[3]
# Out:
# /usr/local/lib/python2.7/dist-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file /usr/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
imgTagList =  soup.find_all('img')
aList = soup.find_all('a')
scriptTags = soup.find_all('script')

# %%
imgTagSrc = []
aHref = []
scriptLink = []
for imgItem, aItem, item in zip(imgTagList,aList, scriptTags):
    try:
        imgTagSrc.append(imgItem['src'])
    except:
        continue
    try:
        aHref.append(aItem['href'])
    except:
        continue
    try:
        scriptLink.append(item['src'])
    except:
        continue

# %%
for link in scriptLink:
    try:
        new_url = requests.get(link).url
        old_domain = urlparse(link).hostname
        new_domain = urlparse(new_url).hostname
    #     if old_domain!=new_domain:
        print "Original URL:", urlparse(link).hostname, "Redirect URL:",urlparse(new_url).hostname
    except:
        print "Invalid URL: ",link
# Out:
# Original URL: consent.cmp.oath.com Redirect URL: consent.cmp.oath.com
# Original URL: consent.cmp.oath.com Redirect URL: consent.cmp.oath.com
# Original URL: mbp.yimg.com Redirect URL: mbp.yimg.com
# Original URL: mbp.yimg.com Redirect URL: mbp.yimg.com
# Original URL: s.yimg.com Redirect URL: s.yimg.com
# Original URL: mbp.yimg.com Redirect URL: mbp.yimg.com
# Original URL: mbp.yimg.com Redirect URL: mbp.yimg.com
# Original URL: mbp.yimg.com Redirect URL: mbp.yimg.com
# Original URL: mbp.yimg.com Redirect URL: mbp.yimg.com
# Original URL: mbp.yimg.com Redirect URL: mbp.yimg.com
# Original URL: mbp.yimg.com Redirect URL: mbp.yimg.com
# Original URL: mbp.yimg.com Redirect URL: mbp.yimg.com
# Original URL: mbp.yimg.com Redirect URL: mbp.yimg.com
# Original URL: mbp.yimg.com Redirect URL: mbp.yimg.com
# Original URL: mbp.yimg.com Redirect URL: mbp.yimg.com
# Original URL: mbp.yimg.com Redirect URL: mbp.yimg.com
# Original URL: mbp.yimg.com Redirect URL: mbp.yimg.com

# %%
links = []
for item in aList:
    try:
        links.append(item['href'])
    except:
        continue

# %%
idx=0
for item in aList:
    attr = item.attrs
    if "target" in attr and attr["target"]=="_blank":
        url = attr["href"]
        if len(url)>50:
            print len(url)
            new_url = requests.get(url).url
            old_domain = urlparse(url).hostname
            new_domain = urlparse(new_url).hostname
            if old_domain!=new_domain:
                print "Original URL:", urlparse(url).hostname, "Redirect URL:",urlparse(new_url).hostname
# Out:
# 104
# 94
# 75
# 84
# 83
# 99
# 75

# %%
import urllib2
from os.path import basename
from urlparse import urlsplit
from bs4 import BeautifulSoup # for HTML parsing

global urlList
urlList = []
fileName = './downloadImages'
# recursively download images starting from the root URL
def downloadImages(url, level): # the root URL is level 0
    print url
    global urlList
    if url in urlList: # prevent using the same URL again
        return
    urlList.append(url)
    try:
        urlContent = urllib2.urlopen(url).read()
    except:
        return

    soup = BeautifulSoup(''.join(urlContent))
    # find and download all images
    imgTags = soup.findAll('img')
    for imgTag in imgTags:
        imgUrl = imgTag['src']
        try:
            imgData = urllib2.urlopen(imgUrl).read()
            fileName = basename(urlsplit(imgUrl)[2])
            output = open(fileName,'wb')
            output.write(imgData)
            output.close()
        except:
            pass

    # if there are links on the webpage then recursively repeat
    if level > 0:
        linkTags = soup.findAll('a')
        if len(linkTags) > 0:
            for linkTag in linkTags:
                try:
                    linkUrl = linkTag['href']
                    downloadImages(linkUrl, level - 1)
                except:
                    pass

# main
downloadImages('http://www.yahoo.com', 1)

# %%
from fake_useragent import UserAgent
ua = UserAgent()
# Out:
# No handlers could be found for logger "root"

# %%
ua.chrome
# Out:
# u'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1664.3 Safari/537.36'

# %%
# Out:
# <!DOCTYPE html>
# <html id="atomic" lang="en-US" class="atomic my3columns ua-wk ua-win ua-4.0 ua-wk537  l-out Pos-r https fp fp-v2 rc1 fp-default mini-uh-on viewer-right two-col ntk-wide ltr desktop Desktop bktGUCE101,FPYT101">
# <head>
#
# ...
